# %%
from __future__ import annotations

from pathlib import Path
import dataretrieval.nwis as nwis
from datetime import datetime
import geopandas as gpd
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import pynhd as nhd
from pynhd import NLDI, NHDPlusHR, WaterData,HP3D
import py3dep
import pygeohydro as gh

from pathlib import Path
import networkx as nx
import xarray as xr
import xrspatial
import os
import contextily as cx
import folium

# %%
nldi = NLDI()
upstream_id = "10155200"
downstream_id = "10155500"
sites=[upstream_id,downstream_id]

basin = nldi.get_basins(feature_ids = sites,fsource = "nwissite")
geometry = basin.geometry.iloc[0]

station_df, metadata = nwis.get_info(sites=sites, seriesCatalogOutput=True)
# Out:
# /Users/lizzieburgon/.local/share/mamba/envs/SVE_Env/lib/python3.10/site-packages/dataretrieval/nwis.py:692: UserWarning: WARNING: Starting in March 2024, the NWIS qw data endpoint is retiring and no longer receives updates. For more information, refer to https://waterdata.usgs.gov.nwis/qwdata and https://doi-usgs.github.io/dataRetrieval/articles/Status.html or email CompTools@usgs.gov.
#   warnings.warn(

# %%
discharge_info = station_df[station_df['parm_cd'] == '00060']
# width_info = station_df[station_df['parm_cd'] == '00004']

# gage_height_info = station_df[station_df['parm_cd'] == '00065']
# gage_2_datum_info = station_df[station_df['parm_cd'] == '30207']

# df = discharge_info[['site_no', 'station_nm', 'begin_date', 'end_date']]
# df = df.drop_duplicates(subset='site_no', keep='first').reset_index(drop=True)

discharge_info.head()
# Out:
#     agency_cd   site_no                                      station_nm  \
# 1        USGS  10155200  PROVO RIV AT RIV ROAD BRIDGE NR HEBER CITY, UT
# 77       USGS  10155200  PROVO RIV AT RIV ROAD BRIDGE NR HEBER CITY, UT
# 83       USGS  10155500                 PROVO RIVER NEAR CHARLESTON, UT
# 92       USGS  10155500                 PROVO RIVER NEAR CHARLESTON, UT
# 169      USGS  10155500                 PROVO RIVER NEAR CHARLESTON, UT
#
#     site_tp_cd  dec_lat_va  dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 1           ST   40.554398  -111.433243            S              NAD83
# 77          ST   40.554398  -111.433243            S              NAD83
# 83          ST   40.484122  -111.463520            S              NAD83
# 92          ST   40.484122  -111.463520            S              NAD83
# 169         ST   40.484122  -111.463520            S              NAD83
#
#       alt_va  alt_acy_va  ...   ts_id  loc_web_ds medium_grp_cd parm_grp_cd  \
# 1    5691.59        0.09  ...  196823         NaN           wat         NaN
# 77   5691.59        0.09  ...  196821         NaN           wat         NaN
# 83   5427.04        0.09  ...  143627         NaN           wat         NaN
# 92   5427.04        0.09  ...       0         NaN           wat         PHY
# 169  5427.04        0.09  ...  144375         NaN           wat         NaN
#
#       srs_id  access_cd  begin_date    end_date count_nu  \
# 1    1645423          0  2001-09-08  2026-03-24     8964
# 77   1645423          0  2001-09-08  2026-03-25     8964
# 83   1645423          0  1938-10-01  2026-03-24    16971
# 92   1645423          0  1971-08-26  1972-07-20        4
# 169  1645423          0  1991-11-23  2026-03-25    12541
#
#                         geometry
# 1     POINT (-111.43324 40.5544)
# 77    POINT (-111.43324 40.5544)
# 83   POINT (-111.46352 40.48412)
# 92   POINT (-111.46352 40.48412)
# 169  POINT (-111.46352 40.48412)
#
# [5 rows x 25 columns]
